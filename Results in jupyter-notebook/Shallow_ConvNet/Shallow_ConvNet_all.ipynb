# %% [markdown]
# # With 1~9 VS all others
#
# <br><br><br>

# %%
#SET 1 vs all others
test_set   = 1
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2271, 1000, 22, 1)
# y_train (2271, 4)
# Training trials = 2271
# Testing  trials = 287
# ----------------------------------------
# Epoch: 0 | test1: 0.2578 | test2: 0.2605 | train: 0.2961 | train Loss: 1.4067 | test Loss: 1.4480
# Epoch: 1 | test1: 0.3449 | test2: 0.3283 | train: 0.2964 | train Loss: 1.4091 | test Loss: 1.3721
# Epoch: 2 | test1: 0.3031 | test2: 0.3014 | train: 0.3774 | train Loss: 1.3603 | test Loss: 1.3927
# Epoch: 3 | test1: 0.3415 | test2: 0.3359 | train: 0.4074 | train Loss: 1.3400 | test Loss: 1.3614
# Epoch: 4 | test1: 0.3798 | test2: 0.3836 | train: 0.4754 | train Loss: 1.2818 | test Loss: 1.3248
# Epoch: 5 | test1: 0.4878 | test2: 0.4387 | train: 0.4431 | train Loss: 1.2931 | test Loss: 1.2852
# Epoch: 6 | test1: 0.4983 | test2: 0.4624 | train: 0.4831 | train Loss: 1.2740 | test Loss: 1.2715
# Epoch: 7 | test1: 0.4704 | test2: 0.4646 | train: 0.4543 | train Loss: 1.2807 | test Loss: 1.2611
# ...

# %%
#SET 2 vs all others
test_set   = 2
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2272, 1000, 22, 1)
# y_train (2272, 4)
# Training trials = 2272
# Testing  trials = 286
# ----------------------------------------
# Epoch: 0 | test1: 0.2483 | test2: 0.2525 | train: 0.2692 | train Loss: 1.4090 | test Loss: 1.4445
# Epoch: 1 | test1: 0.2762 | test2: 0.2775 | train: 0.3161 | train Loss: 1.3744 | test Loss: 1.4123
# Epoch: 2 | test1: 0.2692 | test2: 0.2784 | train: 0.3938 | train Loss: 1.3246 | test Loss: 1.4217
# Epoch: 3 | test1: 0.3007 | test2: 0.2966 | train: 0.4074 | train Loss: 1.3157 | test Loss: 1.3948
# Epoch: 4 | test1: 0.3077 | test2: 0.2813 | train: 0.4466 | train Loss: 1.2875 | test Loss: 1.4174
# Epoch: 5 | test1: 0.2622 | test2: 0.2660 | train: 0.5068 | train Loss: 1.2470 | test Loss: 1.4319
# Epoch: 6 | test1: 0.3042 | test2: 0.2902 | train: 0.5266 | train Loss: 1.2331 | test Loss: 1.4226
# Epoch: 7 | test1: 0.3462 | test2: 0.3248 | train: 0.5388 | train Loss: 1.2261 | test Loss: 1.3804
# ...

# %%
#SET 3 vs all others
test_set   = 3
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2272, 1000, 22, 1)
# y_train (2272, 4)
# Training trials = 2272
# Testing  trials = 286
# ----------------------------------------
# Epoch: 0 | test1: 0.3986 | test2: 0.3524 | train: 0.2802 | train Loss: 1.4280 | test Loss: 1.3495
# Epoch: 1 | test1: 0.4126 | test2: 0.3682 | train: 0.3109 | train Loss: 1.3851 | test Loss: 1.3382
# Epoch: 2 | test1: 0.4336 | test2: 0.4124 | train: 0.3848 | train Loss: 1.3430 | test Loss: 1.3035
# Epoch: 3 | test1: 0.5000 | test2: 0.4785 | train: 0.4382 | train Loss: 1.3105 | test Loss: 1.2487
# Epoch: 4 | test1: 0.4476 | test2: 0.4479 | train: 0.4911 | train Loss: 1.2734 | test Loss: 1.2683
# Epoch: 5 | test1: 0.5350 | test2: 0.5189 | train: 0.4756 | train Loss: 1.2586 | test Loss: 1.1971
# Epoch: 6 | test1: 0.5979 | test2: 0.5574 | train: 0.4551 | train Loss: 1.2727 | test Loss: 1.1740
# Epoch: 7 | test1: 0.6783 | test2: 0.6172 | train: 0.5172 | train Loss: 1.2423 | test Loss: 1.1235
# ...

# %%
#SET 4 vs all others
test_set   = 4
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2274, 1000, 22, 1)
# y_train (2274, 4)
# Training trials = 2274
# Testing  trials = 284
# ----------------------------------------
# Epoch: 0 | test1: 0.2817 | test2: 0.2704 | train: 0.2829 | train Loss: 1.4363 | test Loss: 1.4194
# Epoch: 1 | test1: 0.2817 | test2: 0.2711 | train: 0.2885 | train Loss: 1.4119 | test Loss: 1.4236
# Epoch: 2 | test1: 0.3099 | test2: 0.3010 | train: 0.3574 | train Loss: 1.3726 | test Loss: 1.4016
# Epoch: 3 | test1: 0.3310 | test2: 0.3200 | train: 0.3622 | train Loss: 1.3831 | test Loss: 1.3940
# Epoch: 4 | test1: 0.3768 | test2: 0.3540 | train: 0.4101 | train Loss: 1.3132 | test Loss: 1.3705
# Epoch: 5 | test1: 0.3275 | test2: 0.3272 | train: 0.4736 | train Loss: 1.2882 | test Loss: 1.3927
# Epoch: 6 | test1: 0.3873 | test2: 0.3710 | train: 0.4324 | train Loss: 1.3053 | test Loss: 1.3570
# Epoch: 7 | test1: 0.3838 | test2: 0.3699 | train: 0.4399 | train Loss: 1.2694 | test Loss: 1.3544
# ...

# %%
#SET 5 vs all others
test_set   = 5
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2276, 1000, 22, 1)
# y_train (2276, 4)
# Training trials = 2276
# Testing  trials = 282
# ----------------------------------------
# Epoch: 0 | test1: 0.2518 | test2: 0.2544 | train: 0.3455 | train Loss: 1.3678 | test Loss: 1.4468
# Epoch: 1 | test1: 0.2766 | test2: 0.2592 | train: 0.3622 | train Loss: 1.3650 | test Loss: 1.4348
# Epoch: 2 | test1: 0.2518 | test2: 0.2508 | train: 0.3873 | train Loss: 1.3323 | test Loss: 1.4715
# Epoch: 3 | test1: 0.2624 | test2: 0.2629 | train: 0.4165 | train Loss: 1.3252 | test Loss: 1.4506
# Epoch: 4 | test1: 0.3050 | test2: 0.3053 | train: 0.4868 | train Loss: 1.2676 | test Loss: 1.3964
# Epoch: 5 | test1: 0.2695 | test2: 0.2616 | train: 0.4766 | train Loss: 1.2767 | test Loss: 1.4632
# Epoch: 6 | test1: 0.2908 | test2: 0.2953 | train: 0.4711 | train Loss: 1.2822 | test Loss: 1.4160
# Epoch: 7 | test1: 0.2837 | test2: 0.2900 | train: 0.5002 | train Loss: 1.2482 | test Loss: 1.4193
# ...

# %%
#SET 6 vs all others
test_set   = 6
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2273, 1000, 22, 1)
# y_train (2273, 4)
# Training trials = 2273
# Testing  trials = 285
# ----------------------------------------
# Epoch: 0 | test1: 0.2561 | test2: 0.2546 | train: 0.3323 | train Loss: 1.3840 | test Loss: 1.4602
# Epoch: 1 | test1: 0.2456 | test2: 0.2623 | train: 0.3465 | train Loss: 1.3854 | test Loss: 1.4321
# Epoch: 2 | test1: 0.3298 | test2: 0.3166 | train: 0.3672 | train Loss: 1.3620 | test Loss: 1.3835
# Epoch: 3 | test1: 0.2982 | test2: 0.3048 | train: 0.4280 | train Loss: 1.3226 | test Loss: 1.3928
# Epoch: 4 | test1: 0.2526 | test2: 0.2719 | train: 0.4247 | train Loss: 1.3054 | test Loss: 1.4273
# Epoch: 5 | test1: 0.2632 | test2: 0.2729 | train: 0.4667 | train Loss: 1.2899 | test Loss: 1.4225
# Epoch: 6 | test1: 0.2596 | test2: 0.2700 | train: 0.4801 | train Loss: 1.2514 | test Loss: 1.4367
# Epoch: 7 | test1: 0.2632 | test2: 0.2602 | train: 0.4811 | train Loss: 1.2523 | test Loss: 1.4522
# ...

# %%
#SET 7 vs all others
test_set   = 7
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2270, 1000, 22, 1)
# y_train (2270, 4)
# Training trials = 2270
# Testing  trials = 288
# ----------------------------------------
# Epoch: 0 | test1: 0.2639 | test2: 0.2522 | train: 0.3172 | train Loss: 1.4089 | test Loss: 1.4494
# Epoch: 1 | test1: 0.2569 | test2: 0.2652 | train: 0.2901 | train Loss: 1.4127 | test Loss: 1.4600
# Epoch: 2 | test1: 0.3021 | test2: 0.2878 | train: 0.3837 | train Loss: 1.3712 | test Loss: 1.4093
# Epoch: 3 | test1: 0.2778 | test2: 0.2937 | train: 0.4268 | train Loss: 1.3321 | test Loss: 1.3922
# Epoch: 4 | test1: 0.2917 | test2: 0.2904 | train: 0.4384 | train Loss: 1.3026 | test Loss: 1.3968
# Epoch: 5 | test1: 0.2882 | test2: 0.2875 | train: 0.4715 | train Loss: 1.2606 | test Loss: 1.4166
# Epoch: 6 | test1: 0.2917 | test2: 0.3040 | train: 0.4459 | train Loss: 1.2972 | test Loss: 1.3944
# Epoch: 7 | test1: 0.3194 | test2: 0.3336 | train: 0.4922 | train Loss: 1.2481 | test Loss: 1.3723
# ...

# %%
#SET 8 vs all others
test_set   = 8
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2276, 1000, 22, 1)
# y_train (2276, 4)
# Training trials = 2276
# Testing  trials = 282
# ----------------------------------------
# Epoch: 0 | test1: 0.2589 | test2: 0.2586 | train: 0.2967 | train Loss: 1.4323 | test Loss: 1.4674
# Epoch: 1 | test1: 0.2979 | test2: 0.2954 | train: 0.3114 | train Loss: 1.4057 | test Loss: 1.3918
# Epoch: 2 | test1: 0.2908 | test2: 0.2925 | train: 0.3519 | train Loss: 1.3738 | test Loss: 1.4156
# Epoch: 3 | test1: 0.3440 | test2: 0.3502 | train: 0.3425 | train Loss: 1.3779 | test Loss: 1.3454
# Epoch: 4 | test1: 0.3298 | test2: 0.3509 | train: 0.3388 | train Loss: 1.3723 | test Loss: 1.3502
# Epoch: 5 | test1: 0.4787 | test2: 0.4595 | train: 0.4130 | train Loss: 1.3203 | test Loss: 1.2507
# Epoch: 6 | test1: 0.4113 | test2: 0.4026 | train: 0.4394 | train Loss: 1.3013 | test Loss: 1.2979
# Epoch: 7 | test1: 0.5248 | test2: 0.4990 | train: 0.4866 | train Loss: 1.2619 | test Loss: 1.2188
# ...

# %%
#SET 9 vs all others
test_set   = 9
batch_size = 390
data_list = load_1vs8_data(test_set)
run_model(data_list,batch_size)
# Out:
# x_train (2280, 1000, 22, 1)
# y_train (2280, 4)
# Training trials = 2280
# Testing  trials = 278
# ----------------------------------------
# Epoch: 0 | test1: 0.2482 | test2: 0.2535 | train: 0.3138 | train Loss: 1.4169 | test Loss: 1.4809
# Epoch: 1 | test1: 0.2734 | test2: 0.2873 | train: 0.3005 | train Loss: 1.4158 | test Loss: 1.4290
# Epoch: 2 | test1: 0.2662 | test2: 0.2798 | train: 0.4071 | train Loss: 1.3312 | test Loss: 1.4434
# Epoch: 3 | test1: 0.2770 | test2: 0.2894 | train: 0.3805 | train Loss: 1.3373 | test Loss: 1.4314
# Epoch: 4 | test1: 0.2950 | test2: 0.3037 | train: 0.4091 | train Loss: 1.3102 | test Loss: 1.4213
# Epoch: 5 | test1: 0.3417 | test2: 0.3402 | train: 0.3975 | train Loss: 1.3070 | test Loss: 1.3848
# Epoch: 6 | test1: 0.3597 | test2: 0.3572 | train: 0.4431 | train Loss: 1.2909 | test Loss: 1.3654
# Epoch: 7 | test1: 0.5000 | test2: 0.4488 | train: 0.4626 | train Loss: 1.2713 | test Loss: 1.2799
# ...
